# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
dataset_path = "../dataset"

# %%
classes = [
    "Great Indian Bustard",
    "Greator Flamingo",
    "Indian Skimmer",
    "Stoliczka_s Bushchat",
    "Grey Hypocolius",
    "Macqueen_s Bustard",
    "White-naped Tit",
    "Painted Francolin"
    "Sarus Crane",
    "Asian Desert Warbler",
    "Common Emarld Dove",
    "Indian Peafowl",
    "Indian Grey Hornbill",
    "Baya Weaver"
    "Yellow-eyed Babbler",
    "Ultramarine Flycatcher",
    "Black-necked Stork",
    "Painted Stork",
    "White-eyed Buzzard",
    "Crested Serpent Eagle"
]

# %%
images = []
labels = []

# %%
img_size = 128

for class_name in classes:

    class_path = os.path.join(dataset_path, class_name)

    for img_name in os.listdir(class_path):

        img_path = os.path.join(class_path, img_name)

        try:
            img = cv2.imread(img_path)

            img = cv2.resize(img, (img_size, img_size))

            images.append(img)

            labels.append(class_name)

        except:
            print("Error:", img_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 7
#       3 for class_name in classes:
#       5     class_path = os.path.join(dataset_path, class_name)
# ----> 7     for img_name in os.listdir(class_path):
#       9         img_path = os.path.join(class_path, img_name)
#      11         try:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../dataset\\Painted FrancolinSarus Crane'
